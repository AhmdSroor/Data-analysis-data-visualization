# %%
#category data type
#VI at the start of any code

# %%
import pandas as pd

# %%
movies = pd.read_csv('/home/ahmdsroor/pythoncourse/section 6/P4-Movie-Ratings.csv')

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
movies.Genre.unique()
# Out:
# array(['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance',
#        'Thriller'], dtype=object)

# %%
len(movies)
# Out:
# 559

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating',
       'BudgetMillions', 'Year']

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
movies.Year.unique()
# Out:
# array([2009, 2008, 2010, 2007, 2011])

# %%
movies.CriticRating.unique()
# Out:
# array([87,  9, 30, 93, 55, 39, 40, 50, 43,  5, 79, 13, 89, 72,  4, 54, 53,
#        52, 14,  6, 33, 21, 94, 46, 23, 77, 26, 83, 67, 63,  7, 44, 35, 65,
#        19, 25, 84, 71, 41, 88, 69, 11, 90, 42, 61, 68, 86, 36, 78, 62, 38,
#        81, 28, 22, 24, 20, 12, 80,  1, 17, 66, 29, 47,  2, 91, 59, 48, 92,
#        27, 15, 45, 64, 85, 74, 75,  8, 73, 51,  3, 82, 10, 58, 32, 56, 16,
#        76, 34, 18, 95, 49, 31, 70, 37,  0, 60, 57, 97, 96])

# %%
movies.AudienceRating.unique()
# Out:
# array([81, 44, 52, 84, 70, 63, 71, 57, 48, 93, 51, 89, 40, 64, 46, 56, 43,
#        72, 37, 35, 87, 78, 66, 31, 55, 34, 49, 69, 92, 74, 59, 32, 38, 60,
#        33, 50, 80, 86, 65, 77, 47, 62, 75, 42, 61, 67, 53, 45, 54, 58, 28,
#        79, 76, 83, 73, 68, 36, 90, 85, 82, 91, 24, 26, 41, 29, 27,  0, 39,
#        25, 19, 20, 96, 88, 22])

# %%
movies.Film = movies.Film.astype('category')
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.Genre.describe()
# Out:
# count        559
# unique         7
# top       Comedy
# freq         172
# Name: Genre, dtype: object

# %%
movies.Genre.unique()
# Out:
# [Comedy, Adventure, Action, Horror, Drama, Romance, Thriller]
# Categories (7, object): [Comedy, Adventure, Action, Horror, Drama, Romance, Thriller]

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Joint plots

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating',
                 kind = 'hex')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating',
                 kind = 'reg')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating',
                 kind = 'resid')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating',
                 kind = 'kde')

# %% [markdown]
# ---

# %%
#histograms

# %%
m1 = sns.distplot(movies.AudienceRating)

# %%
m2 = sns.distplot(movies.CriticRating, bins = 15)

# %%
sns.set_style("white")
n1 = plt.hist(movies.AudienceRating, bins = 15)

# %%
n1 = plt.hist(movies.CriticRating, bins = 15)
#to change style back sns.set_style("darkgrid")

# %%
#stacked histograms

# %%
plt.hist(movies.BudgetMillions)
plt.show()

# %%
movies[movies.Genre == "Drama"]
# Out:
#                     Film  Genre  CriticRating  AudienceRating  BudgetMillions  \
# 10            88 Minutes  Drama             5              51              30
# 11    A Dangerous Method  Drama            79              89              20
# 13        A Serious Man   Drama            89              64               7
# 18          Albert Nobbs  Drama            53              43               8
# 23       All Good Things  Drama            33              64              20
# ..                   ...    ...           ...             ...             ...
# 529            War Horse  Drama            77              73              66
# 532  Water For Elephants  Drama            60              72              38
# 534     We Own the Night  Drama            55              63              21
# 541             Whip It   Drama            84              73              15
# 545        Winter's Bone  Drama            94              73               2
#
#      Year
# 10   2007
# ...

# %%
movies[movies.Genre == 'Drama'].BudgetMillions
# Out:
# 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: BudgetMillions, Length: 101, dtype: int64

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Action'].BudgetMillions)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions)
plt.hist(movies[movies.Genre == 'Action'].BudgetMillions)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Action'].BudgetMillions, bins = 15)
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins = 15)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions, bins = 15)
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMillions, movies[movies.Genre == 'Drama'].BudgetMillions], bins = 15, stacked = True)
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print (gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1 = list()
mylabels = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    mylabels.append(gen)


h = plt.hist(list1, bins = 30, stacked = True, rwidth = 1, label = mylabels)
plt.legend()
plt.show()

# %%
#kde plot

# %%
vis1 = sns.lmplot(data = movies, x = 'CriticRating', y = 'AudienceRating',
                 hue = 'Genre', fit_reg = False, size = 7, aspect = 1)

# %%
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating)

# %%
k1b = sns.kdeplot(movies.CriticRating, movies.AudienceRating, cmap = 'Reds')

# %%
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade = True, shade_lowest = False, cmap = 'Reds')

# %%
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade = True, shade_lowest = False, cmap = 'Reds')
k1b = sns.kdeplot(movies.CriticRating, movies.AudienceRating, cmaps = 'Reds')

# %% [markdown]
# ---

# %%
#working with subplots

# %%
sns.set_style('dark')
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating)

# %%
k3 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating)

# %%
f, axes = plt.subplots(1, 2, figsize = (12, 6))
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax = axes[0])
k3 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax = axes[1])

# %%
f, axes = plt.subplots(2, 2, figsize = (12, 6))
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax = axes[1,0])
k3 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax = axes[0,1])

# %%
f, axes = plt.subplots(1, 2, figsize = (12, 6),sharex = True, sharey = True)
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax = axes[0])
k3 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax = axes[1])
k2.set(xlim=(-20, 160))
# Out:
# [(-20, 160)]

# %%
#violinplots

# %%
w = sns.boxplot(data = movies, x = 'Genre', y = 'CriticRating')

# %%
z = sns.violinplot(data = movies, x = 'Genre', y = 'CriticRating')

# %%
w = sns.boxplot(data = movies[movies.Genre == 'Drama'], x = 'Year', y = 'CriticRating')

# %%
z = sns.violinplot(data = movies[movies.Genre == 'Drama'], x = 'Year', y = 'CriticRating')

# %%
#creating a facet grid

# %%
g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')

# %%
g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating')

# %%
#can populate with any kind of charts examle histograms

# %%
g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'BudgetMillions')

# %%
#back to the scatter plot
g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s = 50, linewidth = 0.5, edgecolor = 'Black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating', **kws)

# %%
#controlloing axes and adding diagonal

# %%
g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s = 50, linewidth = 0.5, edgecolor = 'Black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating', **kws)
g.set(xlim = (0, 100), ylim = (0, 100))
for ax in g.axes.flat:
    ax.plot((0,100), (0, 100), c = 'gray', ls = '--')
g.add_legend()

# %%
#building dashboards

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots(2, 2, figsize = (15, 15))
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax = axes[0,0])
k3 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax = axes[0,1])
k2.set(xlim=(-20, 160))
k3.set(xlim=(-20, 160))
z = sns.violinplot(data = movies, x = 'Year', y = 'BudgetMillions',ax = axes[1,0])
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade = True, shade_lowest = False, cmaps = 'Reds', ax = axes[1,1])
k1b = sns.kdeplot(movies.CriticRating, movies.AudienceRating, cmaps = 'Reds', ax = axes[1,1])
plt.show()
#to add chart which isn't sns plot for example histogram
#axes[1,1].hist(movies.CriticRating, bins = 15)

# %% [markdown]
# ---

# %%
#styling dashboards

# %%
sns.set_style('dark', {'axes.facecolor':'black'}) #white, whitegrid, dark, darkgrid, tricks
f, axes = plt.subplots(2, 2, figsize = (15, 15))

# plot 0,0

k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,shade = True, shade_lowest = True, cmap = 'inferno', ax = axes[0,0])
k2b = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, cmap = 'cool', ax = axes[0,0])

#plot 0,1

k3 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating,shade = True, shade_lowest = True, cmap = 'inferno', ax = axes[0,1])
k3b = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, cmap = 'cool', ax = axes[0,1])

#plot 1,0

z = sns.violinplot(data = movies, x = 'Year', y = 'BudgetMillions',ax = axes[1,0], palette = 'YlOrRd')

#plot 1,1

k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade = True, shade_lowest = False, cmap = 'Blues_r', ax = axes[1,1])
k1b = sns.kdeplot(movies.CriticRating, movies.AudienceRating, cmap = 'gist_gray_r', ax = axes[1,1])

k2.set(xlim=(-20, 160))
k3.set(xlim=(-20, 160))
plt.show()

# %% [markdown]
# ---

# %%
#thematic edits

# %%
sns.set_style('whitegrid')
list1 = list()
mylabels = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    mylabels.append(gen)

fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
h = plt.hist(list1, bins = 30, stacked = True, rwidth = 1, label = mylabels)
plt.title('Movie Budget Distribution', fontsize = 35, color = 'DarkBlue', fontname = 'Console')
plt.ylabel('Number of movies', fontsize = 25, color = 'Red')
plt.xlabel('Budget', fontsize = 25, color = 'Green')
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(frameon = True, fancybox = True, shadow = True, framealpha = 1, prop = {'size' : 20})
plt.show()

# %%
#you can specify colors by creating list of colors
#for example : h = plt.hist(list1, bins = 30, stacked = True, rwidth = 1, label = mylabels, color = ["Red", "Blue", "Green", "Yellow", "Black", "Salmon", "Pink"])
